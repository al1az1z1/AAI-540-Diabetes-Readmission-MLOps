# %%
#Clone Notebook 

# !git clone https://github.com/al1az1z1/AAI-540-Diabetes-Readmission-MLOps.git
# Out:
# Cloning into 'AAI-540-Diabetes-Readmission-MLOps'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# Receiving objects:  66% (8/12)
# remote: Total 12 (delta 1), reused 9 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 3.05 MiB | 7.07 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
#Move into Project Folder
# %cd AAI-540-Diabetes-Readmission-MLOps
# Out:
# /home/sagemaker-user/AAI-540-Diabetes-Readmission-MLOps

# %%
#Create S3 Bucket 
import boto3

bucket_name = "aai540-divya-diabetes-mlops"

s3 = boto3.client("s3", region_name="us-east-1")

s3.create_bucket(Bucket=bucket_name)

print("Bucket created!")
# Out:
# Bucket created!

# %%
#Create Data Lake Folders 
folders = [
    "raw/",
    "processed/",
    "feature-store/",
    "athena-results/",
    "models/",
    "batch-output/"
]

for folder in folders:
    s3.put_object(Bucket=bucket_name, Key=folder)

print("Folders created!")
# Out:
# Folders created!

# %%
#Upload to S3 
s3.upload_file(
    "diabetic_data.csv",
    bucket_name,
    "raw/diabetic_data.csv"
)

print("Dataset uploaded!")
# Out:
# Dataset uploaded!

# %%
#Open Gauis's notebook 
setup_data_lake.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Open Gauis's notebook
# ----> 2 setup_data_lake.ipynb
#
# NameError: name 'setup_data_lake' is not defined
